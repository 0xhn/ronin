# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('每日交易量.csv', index_col='date')
data.describe()
# Out:
#               count
# count  2.900000e+02
# mean   7.029674e+05
# std    9.925142e+05
# min    2.100000e+01
# 25%    1.721250e+03
# 50%    3.955935e+05
# 75%    9.552122e+05
# max    7.330123e+06

# %%
data.plot(y='count')
plt.grid(True)
plt.show()

# %%
axie_contract = pd.read_csv('axie_contract每日交易量.csv', index_col='date')
axie_contract.describe()
# Out:
#               count
# count  2.130000e+02
# mean   3.757840e+05
# std    4.684614e+05
# min    3.682000e+03
# 25%    8.930100e+04
# 50%    2.455740e+05
# 75%    4.589590e+05
# max    3.044678e+06

# %%
axie_contract.plot(y='count')
plt.grid(True)
plt.show()

# %%
market_contract = pd.read_csv('market_contract每日交易量.csv', index_col='date')
market_contract.describe()
# Out:
#                count
# count     215.000000
# mean   232918.186047
# std    160574.859828
# min       354.000000
# 25%     57906.000000
# 50%    277994.000000
# 75%    339118.000000
# max    585035.000000

# %%
market_contract.plot(y='count')
plt.grid(True)
plt.show()

# %%
axie_contract_transfer = pd.read_csv('axie_contract_transfer每日交易量.csv', index_col='date')
axie_contract_transfer.describe()
# Out:
#                count
# count     212.000000
# mean   208123.514151
# std    198516.665561
# min      1239.000000
# 25%     38436.000000
# 50%    142394.500000
# 75%    317928.000000
# max    751065.000000

# %%
axie_contract_transfer.plot(y='count')
plt.grid(True)
plt.show()

# %%
market_contract_buy = pd.read_csv('marketcontact_buy每日交易量.csv', index_col='date')
market_contract_buy.describe()
# Out:
#                count
# count     215.000000
# mean    63696.702326
# std     48029.291648
# min        30.000000
# 25%     16136.000000
# 50%     65717.000000
# 75%     88855.500000
# max    216501.000000

# %%
market_contract_buy.plot(y='count')
plt.grid(True)
plt.show()

# %%
market_contract_buy = pd.read_csv('每日活跃地址量.csv', index_col='date')
market_contract_buy.describe()
# Out:
#               count
# count  2.890000e+02
# mean   1.561750e+05
# std    2.302550e+05
# min    1.200000e+01
# 25%    1.320000e+02
# 50%    4.825800e+04
# 75%    2.295930e+05
# max    1.101660e+06

# %%
market_contract_buy.plot(y='count')
plt.grid(True)
plt.show()
